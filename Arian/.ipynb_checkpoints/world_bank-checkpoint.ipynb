# %%
import os
from pathlib import Path
import urllib.request

import pandas as pd
import numpy as np
import io
import requests


def download_world_bank_indicator(indicator_name: str, directory: str = "."):
    directory = Path(directory)
    file_path = directory / (indicator_name + ".csv")
    os.makedirs(directory, exist_ok=True)
    data_url = f"https://api.worldbank.org/indicator/{indicator_name}?format=csv"
    urllib.request.urlretrieve(data_url, file_path)


def extract_series_of_newest_data(csv_path: str):
    df = pd.read_csv(csv_path, index_col=[0, 1], header=0).T
    recent_year = df.apply(pd.Series.last_valid_index)

    nan_indicies = recent_year[recent_year.isna()].index
    no_na_df = df.drop(nan_indicies, axis=1)

    recent_year = no_na_df.apply(pd.Series.last_valid_index)
    recent_data = no_na_df.lookup(recent_year, no_na_df.columns)
    s = pd.Series(recent_data)
    s.index = no_na_df.columns
    return s


def add_new_feature(
    main_df: pd.DataFrame, additional_feature: pd.Series, name: str
) -> pd.DataFrame:
    tmp_df = main_df.set_index("countryterritoryCode")
    additional_feature = additional_feature.reset_index().set_index("Country Code")
    tmp_df[name] = additional_feature[0]
    return tmp_df.reset_index()

# %%
indicator_names = {
    "GDP per capita (current US$)": "NY.GDP.PCAP.CD",
    "Access to electricity (% of population)": "EG.ELC.ACCS.ZS",
    "Current health expenditure per capita (current US$)": "SH.XPD.CHEX.PC.CD",
    "Current health expenditure (% of GDP)": "SH.XPD.CHEX.GD.ZS",
    "Hospital beds (per 1,000 people)": "SH.MED.BEDS.ZS",
    "Rural population (% of total population)": "SP.RUR.TOTL.ZS",
    "Net migration": "SM.POP.NETM",
    "Urban population (% of total population)": "SP.URB.TOTL.IN.ZS"
    
}

# %%
data_dir = Path("data")
dataset_output_path = "DLL_COVID_TRAIN.csv"

# %%
df = pd.read_csv(
    io.StringIO(
        requests.get(
            "https://opendata.ecdc.europa.eu/covid19/casedistribution/csv"
        ).content.decode("utf-8")
    ),
    usecols=[
        "dateRep",
        "cases",
        "deaths",
        "countriesAndTerritories",
        "popData2018",
        "countryterritoryCode",
    ],
    parse_dates=["dateRep"],
    infer_datetime_format=True,
)

for key, value in indicator_names.items():
    download_world_bank_indicator(value, directory=data_dir)
    csv_path = data_dir / (value + ".csv")
    new_feature = extract_series_of_newest_data(csv_path)
    df = add_new_feature(df, new_feature, key)
    
df = df.dropna(subset=["countryterritoryCode"])

# %%
df.head()
# Out:
#   countryterritoryCode    dateRep  cases  deaths countriesAndTerritories  \
# 0                  AFG 2020-04-18     51       1             Afghanistan
# 1                  AFG 2020-04-17     10       4             Afghanistan
# 2                  AFG 2020-04-16     70       2             Afghanistan
# 3                  AFG 2020-04-15     49       2             Afghanistan
# 4                  AFG 2020-04-14     58       3             Afghanistan
#
#    popData2018  GDP per capita (current US$)  \
# 0   37172386.0                    520.896603
# 1   37172386.0                    520.896603
# 2   37172386.0                    520.896603
# 3   37172386.0                    520.896603
# 4   37172386.0                    520.896603
#
#    Access to electricity (% of population)  \
# 0                                     97.7
# 1                                     97.7
# 2                                     97.7
# 3                                     97.7
# 4                                     97.7
#
#    Current health expenditure per capita (current US$)  \
# 0                                           67.12265
# 1                                           67.12265
# 2                                           67.12265
# 3                                           67.12265
# 4                                           67.12265
#
#    Current health expenditure (% of GDP)  Hospital beds (per 1,000 people)  \
# 0                              11.777194                               0.5
# 1                              11.777194                               0.5
# 2                              11.777194                               0.5
# 3                              11.777194                               0.5
# 4                              11.777194                               0.5
#
#    Rural population (% of total population)  Net migration  \
# 0                                    74.505      -314602.0
# 1                                    74.505      -314602.0
# 2                                    74.505      -314602.0
# 3                                    74.505      -314602.0
# 4                                    74.505      -314602.0
#
#    Urban population (% of total population)
# 0                                    25.495
# 1                                    25.495
# 2                                    25.495
# 3                                    25.495
# 4                                    25.495

# %%
df1 = df[['countryterritoryCode', 'cases', 'deaths', 'popData2018', "Urban population (% of total population)"]]
df1 = df1.groupby("countryterritoryCode")
df_cases_cum = df1.sum(level="cases")

# %%
df_cases_cum.corr()
# Out:
#                                              cases    deaths  popData2018  \
# cases                                     1.000000  0.907816     0.242378
# deaths                                    0.907816  1.000000     0.197384
# popData2018                               0.242378  0.197384     1.000000
# Urban population (% of total population)  0.280421  0.311285     0.144660
#
#                                           Urban population (% of total population)
# cases                                                                     0.280421
# deaths                                                                    0.311285
# popData2018                                                               0.144660
# Urban population (% of total population)                                  1.000000

# %%
df["GDP per capita (current US$)"] = pd.to_numeric(df["GDP per capita (current US$)"], errors="coerce")
df.head()
# Out:
#   countryterritoryCode    dateRep  cases  deaths countriesAndTerritories  \
# 0                  AFG 2020-04-18     51       1             Afghanistan
# 1                  AFG 2020-04-17     10       4             Afghanistan
# 2                  AFG 2020-04-16     70       2             Afghanistan
# 3                  AFG 2020-04-15     49       2             Afghanistan
# 4                  AFG 2020-04-14     58       3             Afghanistan
#
#    popData2018  GDP per capita (current US$)  \
# 0   37172386.0                    520.896603
# 1   37172386.0                    520.896603
# 2   37172386.0                    520.896603
# 3   37172386.0                    520.896603
# 4   37172386.0                    520.896603
#
#    Access to electricity (% of population)  \
# 0                                     97.7
# 1                                     97.7
# 2                                     97.7
# 3                                     97.7
# 4                                     97.7
#
#    Current health expenditure per capita (current US$)  \
# 0                                           67.12265
# 1                                           67.12265
# 2                                           67.12265
# 3                                           67.12265
# 4                                           67.12265
#
#    Current health expenditure (% of GDP)  Hospital beds (per 1,000 people)  \
# 0                              11.777194                               0.5
# 1                              11.777194                               0.5
# 2                              11.777194                               0.5
# 3                              11.777194                               0.5
# 4                              11.777194                               0.5
#
#    Rural population (% of total population)  Net migration  \
# 0                                    74.505      -314602.0
# 1                                    74.505      -314602.0
# 2                                    74.505      -314602.0
# 3                                    74.505      -314602.0
# 4                                    74.505      -314602.0
#
#    Urban population (% of total population)
# 0                                    25.495
# 1                                    25.495
# 2                                    25.495
# 3                                    25.495
# 4                                    25.495

# %%
df2 = df[['countryterritoryCode', 'cases','GDP per capita (current US$)', "Urban population (% of total population)", 'Current health expenditure per capita (current US$)', 'Hospital beds (per 1,000 people)']]
df2 = df2.groupby("countryterritoryCode")
df_cases_cum_2 = df2.sum(level="cases")

# %%
df_cases_cum_2.corr()
# Out:
#                                                        cases  \
# cases                                               1.000000
# GDP per capita (current US$)                        0.254654
# Urban population (% of total population)            0.280421
# Current health expenditure per capita (current ...  0.495616
# Hospital beds (per 1,000 people)                    0.170264
#
#                                                     GDP per capita (current US$)  \
# cases                                                                   0.254654
# GDP per capita (current US$)                                            1.000000
# Urban population (% of total population)                                0.700581
# Current health expenditure per capita (current ...                      0.808433
# Hospital beds (per 1,000 people)                                        0.582263
#
#                                                     Urban population (% of total population)  \
# cases                                                                               0.280421
# GDP per capita (current US$)                                                        0.700581
# Urban population (% of total population)                                            1.000000
# Current health expenditure per capita (current ...                                  0.693005
# Hospital beds (per 1,000 people)                                                    0.668841
#
#                                                     Current health expenditure per capita (current US$)  \
# cases                                                                                        0.495616
# GDP per capita (current US$)                                                                 0.808433
# Urban population (% of total population)                                                     0.693005
# Current health expenditure per capita (current ...                                           1.000000
# Hospital beds (per 1,000 people)                                                             0.521260
#
#                                                     Hospital beds (per 1,000 people)
# cases                                                                       0.170264
# GDP per capita (current US$)                                                0.582263
# Urban population (% of total population)                                    0.668841
# Current health expenditure per capita (current ...                          0.521260
# Hospital beds (per 1,000 people)                                            1.000000

# %%
df_cases_cum_2.head()
# Out:
#                       cases  GDP per capita (current US$)  Net migration  \
# countryterritoryCode
# ABW                      96                  6.920172e+05        27108.0
# AFG                     845                  5.208966e+04    -31460200.0
# AGO                      19                  9.610680e+04       897848.0
# ALB                     539                  2.160228e+05     -2869918.0
# AND                     696                  1.513071e+06            0.0
#
#                       Current health expenditure per capita (current US$)  \
# countryterritoryCode
# ABW                                                            0.000000
# AFG                                                         6712.265015
# AGO                                                         3204.869934
# ALB                                                            0.000000
# AND                                                       145468.318359
#
#                       Hospital beds (per 1,000 people)
# countryterritoryCode
# ABW                                                0.0
# AFG                                               50.0
# AGO                                               22.4
# ALB                                              118.9
# AND                                               90.0

# %%
df2 = df[['countryterritoryCode', 'deaths','GDP per capita (current US$)', "Net migration", 'Current health expenditure per capita (current US$)', 'Hospital beds (per 1,000 people)']]
df2 = df2.groupby("countryterritoryCode")
df_cases_cum_2 = df2.sum(level="deaths")

# %%
df_cases_cum_2.corr()
# Out:
#                                                       deaths  \
# deaths                                              1.000000
# GDP per capita (current US$)                        0.261777
# Net migration                                       0.579915
# Current health expenditure per capita (current ...  0.470451
# Hospital beds (per 1,000 people)                    0.183238
#
#                                                     GDP per capita (current US$)  \
# deaths                                                                  0.261777
# GDP per capita (current US$)                                            1.000000
# Net migration                                                           0.307062
# Current health expenditure per capita (current ...                      0.808433
# Hospital beds (per 1,000 people)                                        0.582263
#
#                                                     Net migration  \
# deaths                                                   0.579915
# GDP per capita (current US$)                             0.307062
# Net migration                                            1.000000
# Current health expenditure per capita (current ...       0.504322
# Hospital beds (per 1,000 people)                         0.206655
#
#                                                     Current health expenditure per capita (current US$)  \
# deaths                                                                                       0.470451
# GDP per capita (current US$)                                                                 0.808433
# Net migration                                                                                0.504322
# Current health expenditure per capita (current ...                                           1.000000
# Hospital beds (per 1,000 people)                                                             0.521260
#
#                                                     Hospital beds (per 1,000 people)
# deaths                                                                      0.183238
# GDP per capita (current US$)                                                0.582263
# Net migration                                                               0.206655
# Current health expenditure per capita (current ...                          0.521260
# Hospital beds (per 1,000 people)                                            1.000000

# %%
df_cases_cum_2 = df_cases_cum_2.sort_values("deaths")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-124-bfe21ae798e5> in <module>()
# ----> 1 df_cases_cum_2 = df_cases_cum_2.sort_values("deaths")
#
# ~/anaconda3/envs/amazonei_tensorflow_p36/lib/python3.6/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4717
#    4718             by = by[0]
# -> 4719             k = self._get_label_or_level_values(by, axis=axis)
#    4720
#    4721             if isinstance(ascending, (tuple, list)):
#
# ~/anaconda3/envs/amazonei_tensorflow_p36/lib/python3.6/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1704             values = self.axes[axis].get_level_values(key)._values
#    1705         else:
# -> 1706             raise KeyError(key)
#    1707
#    1708         # Check for duplicates
#
# KeyError: 'deaths'

# %%
submission = pd.read_csv("submission/sample_submission_fix.csv")

# %%
submission.Country.value_counts()
# Out:
# HTI    14
# MSR    14
# VNM    14
# IND    14
# CRI    14
# SRB    14
# SOM    14
# SXM    14
# SWZ    14
# NLD    14
# JEY    14
# SVN    14
# LIE    14
# EST    14
# TCA    14
# DNK    14
# TZA    14
# NAM    14
# GIN    14
# VIR    14
# BHR    14
# BEN    14
# GNB    14
# AUT    14
# SUR    14
# MAR    14
# TLS    14
# ALB    14
# ROU    14
# NCL    14
#        ..
# FRO    14
# AND    14
# IRN    14
# PRI    14
# LBY    14
# TUR    14
# SEN    14
# GUM    14
# ITA    14
# DJI    14
# BDI    14
# LUX    14
# QAT    14
# MKD    14
# EGY    14
# MDA    14
# SLV    14
# JOR    14
# MDV    14
# IRQ    14
# MRT    14
# KEN    14
# MDG    14
# SYC    14
# LKA    14
# FIN    14
# PNG    14
# ECU    14
# PRY    14
# FJI    14
# Name: Country, Length: 202, dtype: int64
