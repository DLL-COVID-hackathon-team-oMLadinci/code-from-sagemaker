# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
cf = pd.read_csv("../Datasets/John_Hopkins/Clean/confirmed.csv", index_col=0)
df = pd.read_csv("../Datasets/John_Hopkins/Clean/deaths.csv", index_col=0)
rf = pd.read_csv("../Datasets/John_Hopkins/Clean/recovered.csv", index_col=0)

# %%
plt.figure(figsize=(20,10)) 
plt.plot(cf['Croatia'])
plt.show()
