# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Converting to Features Format

# %%
cf = pd.read_csv("../Datasets/John_Hopkins/Clean/confirmed_daily.csv", index_col=0)
df = pd.read_csv("../Datasets/John_Hopkins/Clean/deaths_daily.csv", index_col=0)
rf = pd.read_csv("../Datasets/John_Hopkins/Clean/recovered_daily.csv", index_col=0)

# %%
cf = cf.reset_index()
cf = cf.melt(id_vars="Date")
cf.columns = ["date", "country", "confirmed"]

# %%
cf.head(10)
# Out:
#       date      country  confirmed
# 0  1/22/20  Afghanistan        0.0
# 1  1/23/20  Afghanistan        0.0
# 2  1/24/20  Afghanistan        0.0
# 3  1/25/20  Afghanistan        0.0
# 4  1/26/20  Afghanistan        0.0
# 5  1/27/20  Afghanistan        0.0
# 6  1/28/20  Afghanistan        0.0
# 7  1/29/20  Afghanistan        0.0
# 8  1/30/20  Afghanistan        0.0
# 9  1/31/20  Afghanistan        0.0

# %%
df = df.reset_index()
df = df.melt(id_vars="Date")
df.columns = ["date", "country", "deaths"]

# %%
rf = rf.reset_index()
rf = rf.melt(id_vars="Date")
rf.columns = ["date", "country", "recovered"]

# %%
cf["recovered"] = rf["recovered"]
cf["deaths"] = df["deaths"]

# %%
cf.to_csv("../Datasets/features_format.csv")

# %%
df = cf

# %% [markdown]
# ### Adding Country Codes

# %%
c_dict = pd.read_csv("../country_dict.csv")

# %%
c_dict["country"] = c_dict["country"].str.replace("_", " ")
c_dict = c_dict.set_index("country")
c_dict.head(5)
# Out:
#             code
# country
# Afghanistan  AFG
# Albania      ALB
# Algeria      DZA
# Andorra      AND
# Angola       AGO

# %%
code_dict = c_dict.to_dict()['code']

# %%
dict_entries = set(code_dict.keys())
df_entries = set(df["country"].unique())

# %%
df_entries.difference(dict_entries)
# Out:
# {'Brunei',
#  'Burma',
#  'Cabo Verde',
#  'Congo (Brazzaville)',
#  'Congo (Kinshasa)',
#  "Cote d'Ivoire",
#  'Curacao',
#  'Diamond Princess',
#  'Guinea-Bissau',
#  'Korea, South',
#  'MS Zaandam',
#  'Taiwan*',
#  'Tanzania',
#  'Timor-Leste',
#  'Turks and Caicos Islands',
#  'US',
#  'West Bank and Gaza',
#  'Western Sahara'}

# %%
dict_entries.difference(df_entries)
# Out:
# {'Brunei Darussalam',
#  'Cape Verde',
#  'Congo',
#  'Cote dIvoire',
#  'Curaçao',
#  'Democratic Republic of the Congo',
#  'Guam',
#  'Guernsey',
#  'Guinea Bissau',
#  'Jersey',
#  'Myanmar',
#  'Northern Mariana Islands',
#  'Palestine',
#  'Puerto Rico',
#  'South Korea',
#  'Taiwan',
#  'Timor Leste',
#  'Turks and Caicos islands',
#  'United Republic of Tanzania',
#  'United States Virgin Islands',
#  'United States of America'}

# %%
correction_dict = {
    "Brunei": "Brunei Darussalam",
    "Burma": "Myanmar",
    "Cabo Verde": "Cape Verde",
    "Congo (Brazzaville)": "Congo",
    "Congo (Kinshasa)": "Democratic Republic of the Congo",
    "Cote d'Ivoire": "Cote dIvoire",
    "Guinea-Bissau": "Guinea Bissau",
    "Korea, South": "South Korea",
    "Taiwan*": "Taiwan",
    "Tanzania": "United Republic of Tanzania",
    "Timor-Leste": "Timor Leste",
    "US": "United States of America",
    "West Bank and Gaza": "Palestine",
    "Turks and Caicos Islands": "Turks and Caicos islands",
    "Curacao": "Curaçao"
}

# %%
df["country"] = df["country"].apply(lambda x: correction_dict[x] if x in correction_dict.keys() else x)

# %%
dict_entries = set(code_dict.keys())
df_entries = set(df["country"].unique())
df_entries.difference(dict_entries)
# Out:
# {'Diamond Princess', 'MS Zaandam', 'Western Sahara'}

# %%
dict_entries.difference(df_entries)
# Out:
# {'Guam',
#  'Guernsey',
#  'Jersey',
#  'Northern Mariana Islands',
#  'Puerto Rico',
#  'United States Virgin Islands'}

# %%
df["country_code"] = df["country"].map(code_dict)

# %%
len(df)
# Out:
# 17313

# %%
df = df.dropna()

# %%
len(df)
# Out:
# 17052

# %%
df
# Out:
#           date      country  confirmed  recovered  deaths country_code
# 0      1/22/20  Afghanistan        0.0        0.0     0.0          AFG
# 1      1/23/20  Afghanistan        0.0        0.0     0.0          AFG
# 2      1/24/20  Afghanistan        0.0        0.0     0.0          AFG
# 3      1/25/20  Afghanistan        0.0        0.0     0.0          AFG
# 4      1/26/20  Afghanistan        0.0        0.0     0.0          AFG
# 5      1/27/20  Afghanistan        0.0        0.0     0.0          AFG
# 6      1/28/20  Afghanistan        0.0        0.0     0.0          AFG
# 7      1/29/20  Afghanistan        0.0        0.0     0.0          AFG
# 8      1/30/20  Afghanistan        0.0        0.0     0.0          AFG
# 9      1/31/20  Afghanistan        0.0        0.0     0.0          AFG
# 10      2/1/20  Afghanistan        0.0        0.0     0.0          AFG
# 11      2/2/20  Afghanistan        0.0        0.0     0.0          AFG
# ...

# %%
df.to_csv("../Datasets/features_format.csv")
