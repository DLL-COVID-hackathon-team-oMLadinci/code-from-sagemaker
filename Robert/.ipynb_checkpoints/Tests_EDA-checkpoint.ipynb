# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("../Datasets/Wikipedia/tests.csv")

# %%
df = df.sort_values("%")

# %%
df.columns = ['country', "date", "n_tests", "n_positive", "pct_positive", "test_by_million", "pos_by_million"]

# %%
df.head(5)
# Out:
#                  country    date  n_tests n_positive  pct_positive  \
# 85           North Korea   2 Apr      709          0          0.00
# 65                 Nepal  18 Apr   27,467         30          0.11
# 60               Vietnam  18 Apr  206,253        268          0.13
# 1   United Arab Emirates  15 Apr  767,000      5,365          0.70
# 58             Taiwan[a]  18 Apr   52,445        398          0.76
#
#    test_by_million pos_by_million
# 85              28              0
# 65             978            1.1
# 60           2,089            2.7
# 1           79,901            559
# 58           2,205             17

# %%
df['test_by_million'] = df['test_by_million'].str.replace(",", "")
df['n_tests'] = df['n_tests'].str.replace(",", "")
df['n_positive'] = df['n_positive'].str.replace(",", "")

# %%
df.head(5)
# Out:
#                  country    date  n_tests n_positive  pct_positive  \
# 85           North Korea   2 Apr      709          0          0.00
# 65                 Nepal  18 Apr   27,467         30          0.11
# 60               Vietnam  18 Apr  206,253        268          0.13
# 1   United Arab Emirates  15 Apr  767,000      5,365          0.70
# 58             Taiwan[a]  18 Apr   52,445        398          0.76
#
#     test_by_million pos_by_million
# 85             28.0              0
# 65            978.0            1.1
# 60           2089.0            2.7
# 1           79901.0            559
# 58           2205.0             17

# %%
df['test_by_million']=df['test_by_million'].astype('float32')
df['n_tests']=df['n_tests'].astype('int32')
df['n_positive']=df['n_positive'].astype('int32')
df['test_by_million']=df['test_by_million'].astype('float32')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-d5de1f6074c8> in <module>()
#       1 df['test_by_million']=df['test_by_million'].astype('float32')
# ----> 2 df['n_tests']=df['n_tests'].astype('int32')
#       3 df['n_positive']=df['n_positive'].astype('int32')
#       4 df['test_by_million']=df['test_by_million'].astype('float32')
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5689             # else, only a single dtype is given
#    5690             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5691                                          **kwargs)
#    5692             return self._constructor(new_data).__finalize__(self)
#    5693
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/pandas/core/internals/managers.py in astype(self, dtype, **kwargs)
#     529
#     530     def astype(self, dtype, **kwargs):
# --> 531         return self.apply('astype', dtype=dtype, **kwargs)
#     532
#     533     def convert(self, **kwargs):
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/pandas/core/internals/managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     393                                             copy=align_copy)
#     394
# --> 395             applied = getattr(b, f)(**kwargs)
#     396             result_blocks = _extend_blocks(applied, result_blocks)
#     397
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors, values, **kwargs)
#     532     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     533         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 534                             **kwargs)
#     535
#     536     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/pandas/core/internals/blocks.py in _astype(self, dtype, copy, errors, values, **kwargs)
#     631
#     632                     # _astype_nansafe works fine with 1-d only
# --> 633                     values = astype_nansafe(values.ravel(), dtype, copy=True)
#     634
#     635                 # TODO(extension)
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     681         # work around NumPy brokenness, #1987
#     682         if np.issubdtype(dtype.type, np.integer):
# --> 683             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     684
#     685         # if we have a datetime/timedelta array of objects
#
# pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: '27,467'

# %%
df.describe()
# Out:
#        pct_positive  test_by_million
# count     86.000000        86.000000
# mean       8.882558       124.490181
# std        6.821342       249.778137
# min        0.000000         1.250000
# 25%        3.925000         4.500500
# 50%        7.750000        14.438000
# 75%       11.475000        47.112501
# max       32.000000       978.000000

# %%
objects = df.Country
y_pos = np.arange(len(objects))

percent_pos = df['%']
test_mill = df['Tests /\nmillion\npeople']

fig, axs = plt.subplots(2, figsize=(30,20), sharex=True)
axs[0].bar(y_pos, percent_pos, align='center', alpha=0.5)
axs[1].bar(y_pos, test_mill, align='center', alpha=0.5)

plt.xticks(y_pos, objects)
plt.xticks(rotation='vertical')

plt.show()
