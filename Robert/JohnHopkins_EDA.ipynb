# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
cf = pd.read_csv("../Datasets/John_Hopkins/Clean/confirmed_cumulative.csv", index_col=0)
df = pd.read_csv("../Datasets/John_Hopkins/Clean/deaths_cumulative.csv", index_col=0)
rf = pd.read_csv("../Datasets/John_Hopkins/Clean/recovered_cumulative.csv", index_col=0)

# %%
plt.figure(figsize=(20,10)) 
plt.plot(cf['Croatia'])
plt.show()

# %%
cff = pd.read_csv("../Datasets/John_Hopkins/Clean/confirmed_daily.csv", index_col=0)
dff = pd.read_csv("../Datasets/John_Hopkins/Clean/deaths_daily.csv", index_col=0)
rff = pd.read_csv("../Datasets/John_Hopkins/Clean/recovered_daily.csv", index_col=0)

# %%
plt.figure(figsize=(20,10)) 
plt.plot(cff['Croatia'])
plt.show()
